# %% [markdown]
# <a href="https://colab.research.google.com/github/anushka-cs04/Data-Science-AI/blob/main/Module_1_Python_Programming_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Anushka"
age= 25
salary= 65350
print(name)
print(age)
print(salary)
# Out:
# Anushka
# 25
# 65350

# %% [markdown]
# Assigning Values To Variable
#
#    1. Basic Assignment

# %%
x=5
y=3.14
z= "hi"
print(x)
print(y)
print(z)
# Out:
# 5
# 3.14
# hi

# %% [markdown]
#   2. Dynamic Typing

# %%
y=10
x= "Anushka"
z=2.5
print(type(y))
print(type(x))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
#    3. Assigning Same Value

# %%
a=b=c=100
print(a,b,c)
# Out:
# 100 100 100

# %% [markdown]
#   4.Assigning Different Values

# %%
x,y,z,=1,2.5, "Python"
print(x,y,z)
# Out:
# 1 2.5 Python

# %% [markdown]
# Data Type

# %% [markdown]
#  Numeric Data Type
#
#    1. Integer

# %%
age=25
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
#   2. Float

# %%
price=99.99
print(type(price))
# Out:
# <class 'float'>

# %% [markdown]
#   3. Complex

# %%
x=3+4j
print(x)
print(type(x))
# Out:
# (3+4j)
# <class 'complex'>

# %% [markdown]
# Sequence Data Type

# %% [markdown]
#   1. String

# %%
s= 'Welcome to BBD'
print(s)
print(type(s))
# Out:
# Welcome to BBD
# <class 'str'>

# %% [markdown]
#   2.List

# %%
a= [1,2,3]
print (a)
print(type(a))
b=["BBD","BBD","BBD",4,5]
print(b)
print(type(b))
# Out:
# [1, 2, 3]
# <class 'list'>
# ['BBD', 'BBD', 'BBD', 4, 5]
# <class 'list'>

# %% [markdown]
#   3. Tuples

# %%
t1=(1)
print(type(t1))

t2= ('BBD','BBD','BBD',1,2)
print(t2)
print(t2)
# Out:
# <class 'int'>
# ('BBD', 'BBD', 'BBD', 1, 2)
# ('BBD', 'BBD', 'BBD', 1, 2)

# %% [markdown]
# Set Data Type

# %% [markdown]
# set

# %%
s1={"a","a","b","c","b"}
print(s1)

s2= {"BBD","FOR","BBD"}
for i in s2:
  print(i)
# Out:
# {'a', 'b', 'c'}
# FOR
# BBD

# %% [markdown]
# Dictionary Data Type

# %%
d = {1: 'BBD', 2: 'For',3: 'BBD'}
print(d[1])
print(d.get(2))
# Out:
# BBD
# For

# %% [markdown]
# # **Operators**

# %% [markdown]
# #1.Arithmetic Operator

# %%
a=15
b=4
print("Addition:", a+b)
print("Subtraction:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Floor Division:",a//b)
print("Modulus:",a%b)
print("Exponentiation:",a**b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Exponentiation: 50625

# %% [markdown]
# # 2.Comparision Operator

# %%
a= 13
b= 33
print(a > b)
print(a < b)
print(a == b)
print(a != b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# # 3.Logical Operator

# %%
a= True
b= False
print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %% [markdown]
# # 4. Bitwise Operator

# %%
a=10
b=4
print(~a)
print(a<<b)
print(a&b)
print(a^b)
print(a|b)
print(a>>b)
# Out:
# -11
# 160
# 0
# 14
# 14
# 0

# %% [markdown]
# # 5. Assignment Operator

# %%
a=10
b=a
print(b)
b += a
print(b)
b -= a
print(b)
b *= a
print(b)
b <<= a
print(b)
# Out:
# 10
# 20
# 10
# 100
# 102400

# %% [markdown]
# # 6. Identity Operator

# %%
a = 10
b = 20
c= a
print(a is not b)
print(a is c)
# Out:
# True
# True

# %% [markdown]
# # 7. Membership Operator

# %%
x=24
y=20
my_list = [10,20,30,40,50]
if (x not in my_list):
  print("x is NOT present in given list")
else:
  print("x is present in given list")

if (y in my_list):
  print("y is present in given list")
else:
  print("y is NOT present in given list ")
# Out:
# x is NOT present in given list
# y is present in given list

# %% [markdown]
# # 8. Ternary Operator

# %%
a,b=10,20
min = a if a < b else b
print (min)
# Out:
# 10

# %% [markdown]
# # question
#  1. take two no. as input from the user and perform all arithmetic operations

# %%
a=10
b=15
print("Addition:", a+b)
print("Subtraction:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Floor Division:",a//b)
print("Modulus:",a%b)
print("Exponentiation:",a**b)
# Out:
# Addition: 25
# Subtraction: -5
# Multiplication: 150
# Division: 0.6666666666666666
# Floor Division: 0
# Modulus: 10
# Exponentiation: 1000000000000000

# %% [markdown]
# 2. check whether a specific course is available inthe course catalog

# %%
courses =["Python","Java","c++","Data Science"]
course = input("enter course name:")
if course in courses:
  print("Course is available")
else:
  print("Course is not available")
# Out:
# enter course name:Java
# Course is available

# %% [markdown]
# 3. create a simple login validation system using a username and password.

# %%
username = input("Enter username:")
password=input("Enter password:")

if username == "anushka" and password == "1234":
  print("Login Succesful")
else:
  print("Invalid Usernae or Password")
# Out:
# Enter username:anushka
# Enter password:1234
# Login Succesful

# %% [markdown]
# 4. An employee is eligible for a bonus only if:
#    salary is greater than 30,000
#    experience is greater than 2 years
#    write a program to determine eligiblity

# %%
salary = float(input("Enter salary:"))
experience= float(input("Enter experience (years):"))

if salary >30000 and experience >2:
  print("Eligible for bonus")
else:
  print("Not Eligible for bonus")
# Out:
# Enter salary:50000
# Enter experience (years):3
# Eligible for bonus

# %% [markdown]
# #**Conditional Statements**

# %% [markdown]
# #1.If Statement

# %%
age=22
if age >=18:
  print("Eligible to vote")
# Out:
# Eligible to vote

# %% [markdown]
# #Short-hand if

# %%
age=19
if age >18: print("Eligible to vote")
# Out:
# Eligible to vote

# %% [markdown]
# #2.If else Statement

# %%
age = 10
if age <=12:
  print("Travel for free.")
else:
  print("Pay for ticket.")
# Out:
# Travel for free.

# %% [markdown]
# #3.If-elif-else Statement

# %%
age = 25
if age <=12:
  print("Child.")
elif age <=19:
  print("Teenager.")
elif age <=35:
  print("Young adult")
else:
  print("Adult")
# Out:
# Young adult

# %% [markdown]
# #4. Nested if-else Statement

# %%
age=70
is_member=True

if age >=60:
  if is_member:
    print("30% senior discount!")
  else:
    print("20% senior discount!")
else:
  print("Not eligible for a senior discount.")
# Out:
# 30% senior discount!

# %% [markdown]
# #**Loops**

# %% [markdown]
# #1.for Loop

# %%
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Example 2: Iterate Through a LIST

# %%
fruits=["Apple","Banana","Mango"]

for fruit in fruits:
  print(fruit)
# Out:
# Apple
# Banana
# Mango

# %% [markdown]
# #2.While Loop

# %%
count=1
while count <=5:
  print (count)
  count +=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# #3.Loop Control Statements
#
# A. break

# %%
for i in range(1,10):
  if i ==5:
    break
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# B. continue

# %%
for i in range(1,6):
  if i ==3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5

# %% [markdown]
# C. pass

# %%
for i in range(5):
   pass
print("Loop completed")
# Out:
# Loop completed

# %% [markdown]
# #4.Nested Loops

# %%
for i in range (1,4):
  for j in range (1,4):
    print(i,j)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3

# %% [markdown]
# # questions on conditions and loops
#
# 1. take a number from the user and calculate the sum of all numbers from 1 to N

# %%
n=int(input("Enter N:"))
sum = 0

for i in range (1,n+1):
  sum +=i

print("Sum =",sum)
# Out:
# Enter N:4
# Sum = 10

# %% [markdown]
#  2.Allow the user to enter a passworduntil the correct password is entered.

# %%
correct_password="anushka123"

while True:
  password = input("Enter password:")

  if password == correct_password:
   print("Access Granted")
   break
else:
   print("Wrong Password")
# Out:
# Enter password:anushka123
# Access Granted

# %% [markdown]
#  3. Find how many positive numbers are present in a list

# %%
numbers = [10,-5,7,-2,15,0]
count=0

for num in numbers:
  if num>0:
    count +=1
print("Positive numbers=",count)
# Out:
# Positive numbers= 3

# %% [markdown]
#  4.Check whether monthly sales achieved the target.

# %%
sales = float(input("Enter sales"))

# %% [markdown]
# #**Functions**
#
# #1.Function in Python

# %%
def greet():
  print("Welcome to BBD")
greet()
# Out:
# Welcome to BBD

# %% [markdown]
# # 2.Function with Parameters

# %%
def greet(name):
  print("Hello",name)

greet("Anushka")
# Out:
# Hello Anushka

# %% [markdown]
# #3.Function with Multiple Parameter

# %%
def add(a,b):
  print(a+b)
add(10,20)
# Out:
# 30

# %% [markdown]
# #4.Function with Return Statement

# %%
def square(num):
  return num*num

result = square(5)
print(result)
# Out:
# 25

# %% [markdown]
# #5.Default Parameter

# %%
def country(name="India"):
  print("Country:", name)

country()
country("USA")
# Out:
# Country: India
# Country: USA

# %% [markdown]
# #6.Keyword Arguments

# %%
def student(name, age):
    print(name,age)

student(age=21,name="Anushka")
# Out:
# Anushka 21

# %% [markdown]
# #7.Variable Length Arguments(*args)

# %%
def total(*numbers):
  print(sum(numbers))

total(10,20,30)
# Out:
# 60

# %% [markdown]
# #8.Keyword Variable Arguments (**kwargs)

# %%
def info(**details):
  print(details)

info(name="Anushka", city="Lucknow")
# Out:
# {'name': 'Anushka', 'city': 'Lucknow'}

# %% [markdown]
# #9.Lambda Function

# %%
square = lambda x: x*x
print(square(6))
# Out:
# 36

# %% [markdown]
# #10.Functions with Lists

# %%
def average(numbers):
  return sum(numbers)/len(numbers)

data= [10,20,30,40,50]

print(average(data))
# Out:
# 30.0

# %% [markdown]
# #Questions
#
# 1.Employee salary calculator
# create a function that calculates the final salary of an employee after adding bonus and dedecting tax.

# %%
def salary_calculator(salary,bonus,tax):
  final_salary= salary + bonus- tax
  return final_salary

salary=float(input("Enter salary:"))
bonus=float(input("Enter bonus:"))
tax=float(input("Enter tax:"))

print("Final Salary =", salary_calculator(salary,bonus,tax))
# Out:
# Enter salary:30000
# Enter bonus:2500
# Enter tax:1000
# Final Salary = 31500.0

# %% [markdown]
# 2.Student Result Analysis System
# Create a function that accepts marks of multiple subjects using *args and calculates total, average , and grade.

# %%
def result(*marks):
  total=sum(marks)
  average = total/len(marks)

  if average>=90:
    grade = "A+"
  elif average >=75:
    grade="A"
  elif average >=60:
    grade="B"
  elif average >=40:
    grade="C"
  else:
    grade="Fail"

  print("Total=",total)
  print("Average=",average)
  print("Grade=",grade)

result(85,90,78,88,92)
# Out:
# Total= 433
# Average= 86.6
# Grade= A

# %% [markdown]
# 3.Customer information Management System
# Use **kwargs to store customer details dynamically.

# %%
def customer_info(**kwargs):
  print("Customer Details:")
  for key, value in kwargs.items():
    print(key,":",value)

customer_info(
    Name ="Anushka",
    Age=21,
    City="Lucknow",
    Phone="9005599450"
)
# Out:
# Customer Details:
# Name : Anushka
# Age : 21
# City : Lucknow
# Phone : 9005599450

# %% [markdown]
# #10.Function with NumPy Arrays
